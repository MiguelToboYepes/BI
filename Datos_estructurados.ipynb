# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelToboYepes/BI/blob/main/Datos_estructurados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Datos estructurados
#
# En lo que respecta a los datos estructurados, iniciaremos con la lectura de archivos en formato excel.

# %%
# importamos las librerias

# %%
import pandas as pd

# %%
#Cargar la base de datos

emily_hoteles = pd.read_excel ("/content/BI datos.xlsx", sheet_name= "Hoja1")
emily_vuelos = pd.read_excel ("/content/BI datos.xlsx", sheet_name = "Hoja2")

# %%
emily_hoteles
# Out:
#       Nombre del hotel    Precio  Reviews  Score
# 0      The Red Hut  Inn   726.00      147    7.8
# 1        Jovilee Hotel   1019.00       11    9.8
# 2           See Belize   1031.00        2    2.0
# 3  Best Time Inn Hotel   1049.33      168    6.8
# 4               Sky Inn  1102.45       26    9.0
# 5                  Caye  1102.45       17    9.2
# 6            Db Towers   1137.82       46    8.4
# 7             Easy Inn   1163.29      162    7.8
# 8        Ramada Belize   1186.45     1001    6.4
# 9    Golden Tree Hotel   1217.20        2    5.0

# %%
emily_hoteles.head()
# Out:
#       Nombre del hotel    Precio  Reviews  Score
# 0      The Red Hut  Inn   726.00      147    7.8
# 1        Jovilee Hotel   1019.00       11    9.8
# 2           See Belize   1031.00        2    2.0
# 3  Best Time Inn Hotel   1049.33      168    6.8
# 4               Sky Inn  1102.45       26    9.0

# %%
emily_vuelos.tail()
# Out:
#            Aerolinea  Precio  Escalas  Tiempo de vuelo
# 3             United  408.05         1         04:27:00
# 4  American Airlines  408.05         1         06:38:00
# 5             United  408.05         1         09:03:00
# 6             United  408.05         1         10:28:00
# 7             United  408.05         1         11:15:00

# %%
emily_vuelos.describe()
# Out:
#            Precio  Escalas
# count    8.000000  8.000000
# mean   406.706250  0.875000
# std      3.800699  0.353553
# min    397.300000  0.000000
# 25%    408.050000  1.000000
# 50%    408.050000  1.000000
# 75%    408.050000  1.000000
# max    408.050000  1.000000

# %%
# mostrar las aerolineas

aerolineas = emily_vuelos ["Aerolinea"]

# %%
#Impresion
aerolineas
# Out:
# 0      Alaska airlines
# 1    American Airlines
# 2               United
# 3               United
# 4    American Airlines
# 5               United
# 6               United
# 7               United
# Name: Aerolinea, dtype: object

# %%
unicas = aerolineas.unique() #SELECCIONAMOS LOS VALORES QUE NO SE REPITEN Y LOS ALMACENAMOS EN LA VARIABLE UNICA

# %%
unicas[0:3]
# Out:
# array(['Alaska airlines', 'American Airlines', 'United'], dtype=object)

# %%
unicas.tolist() # convierte el arreglo en una lista
# Out:
# ['Alaska airlines', 'American Airlines', 'United']

# %% [markdown]
# Ahora se necesita saber cual es la aerolinea que tiene el valor mas bajo en el tiquete

# %%
# prompt: saber cual es la mas barata

emily_vuelos ('Aerolinea')['Precio'].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-e724cf767ee0> in <cell line: 3>()
#       1 # prompt: saber cual es la mas barata
#       2
# ----> 3 emily_vuelos ('Aerolinea')['Precio'].min()
#
# TypeError: 'DataFrame' object is not callable

# %%
min_precio = emily_vuelos ["Precio"].idxmin()
ahorro = emily_vuelos['Aerolinea'].loc[min_precio]
ahorro
# Out:
# 'Alaska airlines'
